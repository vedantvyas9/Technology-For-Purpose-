# %%
#modules
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
import texttable
from tabulate import tabulate

# %%
#excel file input
dataset = pd.read_excel('/Users/vedantvyas/Desktop/July-November Data.xlsx')
dataset
# Out:
#      Villa No.July  July Water Reading Villa No. Aug  Aug Water Reading  \
# 0              1.0                 0.0             1                0.0
# 1              2.0                20.0             2               11.0
# 2              3.0                 6.0             3               20.0
# 3              4.0                23.0             4               38.0
# 4              5.0                 0.0             5                5.0
# ..             ...                 ...           ...                ...
# 692          693.0                88.0           696               17.0
# 693            NaN                 NaN           697               49.0
# 694            NaN                 NaN           NaN                NaN
# 695            NaN                 NaN           NaN                NaN
# 696            NaN                 NaN           NaN                NaN
#
#     Villa No. Sep  Sep Water Reading Villa No. Oct  Oct Water Reading  \
# ...

# %%
#JUNE
#Top 50 Water Consumers
test = dataset.sort_values(['Jun Water Reading'], ascending = [False])
b =test[['Villa No. Jun', 'Jun Water Reading']]
info = b.head(50)
print(tabulate(info, headers = 'keys', tablefmt = 'grid', showindex = False))
# Out:
# +-----------------+---------------------+
# |   Villa No. Jun |   Jun Water Reading |
# +=================+=====================+
# |             387 |                 293 |
# +-----------------+---------------------+
# |              72 |                 153 |
# +-----------------+---------------------+
# |              37 |                 151 |
# +-----------------+---------------------+
# |             314 |                 144 |
# +-----------------+---------------------+
# |             126 |                 114 |
# +-----------------+---------------------+
# |             379 |                 103 |
# +-----------------+---------------------+
# |             383 |                 100 |
# +-----------------+---------------------+
# |             272 |                  99 |
# +-----------------+---------------------+
# |             157 |                  85 |
# +-----------------+---------------------+
# |             106 |                  84 |
# ...

# %%
#July
#Top 50 Water Consumers
test = dataset.sort_values(['July Water Reading'], ascending = [False])
b =test[['Villa No.July', 'July Water Reading']]
info = b.head(50)
print(tabulate(info, headers = 'keys', tablefmt = 'grid', showindex = False))
# Out:
# +-----------------+----------------------+
# |   Villa No.July |   July Water Reading |
# +=================+======================+
# |             331 |                  198 |
# +-----------------+----------------------+
# |              74 |                  173 |
# +-----------------+----------------------+
# |             141 |                  160 |
# +-----------------+----------------------+
# |              69 |                  142 |
# +-----------------+----------------------+
# |              78 |                  130 |
# +-----------------+----------------------+
# |              37 |                  128 |
# +-----------------+----------------------+
# |             132 |                  117 |
# +-----------------+----------------------+
# |             119 |                  101 |
# +-----------------+----------------------+
# |             108 |                   97 |
# +-----------------+----------------------+
# |             324 |                   89 |
# ...

# %%
#August
#Top 50 Water Consumers
test = dataset.sort_values(['Aug Water Reading'], ascending = [False])
b =test[['Villa No. Aug', 'Aug Water Reading']]
info = b.head(50)
print(tabulate(info, headers = 'keys', tablefmt = 'grid', showindex = False))
# Out:
# +-----------------+---------------------+
# | Villa No. Aug   |   Aug Water Reading |
# +=================+=====================+
# | 147             |                  97 |
# +-----------------+---------------------+
# | 149             |                  94 |
# +-----------------+---------------------+
# | 126             |                  86 |
# +-----------------+---------------------+
# | 107             |                  86 |
# +-----------------+---------------------+
# | 648             |                  85 |
# +-----------------+---------------------+
# | 256             |                  79 |
# +-----------------+---------------------+
# | 138             |                  79 |
# +-----------------+---------------------+
# | 709             |                  78 |
# +-----------------+---------------------+
# | 169             |                  76 |
# +-----------------+---------------------+
# | 373-C           |                  76 |
# ...

# %%
#September
#Top 50 Water Consumers
test = dataset.sort_values(['Sep Water Reading'], ascending = [False])
b =test[['Villa No. Sep', 'Sep Water Reading']]
info = b.head(50)
print(tabulate(info, headers = 'keys', tablefmt = 'grid', showindex = False))
# Out:
# +-----------------+---------------------+
# | Villa No. Sep   |   Sep Water Reading |
# +=================+=====================+
# | 814             |                 199 |
# +-----------------+---------------------+
# | 15              |                 148 |
# +-----------------+---------------------+
# | 107             |                 106 |
# +-----------------+---------------------+
# | 147             |                 105 |
# +-----------------+---------------------+
# | 149             |                 104 |
# +-----------------+---------------------+
# | 169             |                  92 |
# +-----------------+---------------------+
# | 148             |                  92 |
# +-----------------+---------------------+
# | 36              |                  90 |
# +-----------------+---------------------+
# | 67              |                  87 |
# +-----------------+---------------------+
# | 126             |                  81 |
# ...

# %%
#October
#Top 50 Water Consumers
test = dataset.sort_values(['Oct Water Reading'], ascending = [False])
b =test[['Villa No. Oct', 'Oct Water Reading']]
info = b.head(50)
print(tabulate(info, headers = 'keys', tablefmt = 'grid', showindex = False))
# Out:
# +-----------------+---------------------+
# | Villa No. Oct   |   Oct Water Reading |
# +=================+=====================+
# | 149             |                 171 |
# +-----------------+---------------------+
# | 96              |                 129 |
# +-----------------+---------------------+
# | 709             |                 113 |
# +-----------------+---------------------+
# | 355             |                 104 |
# +-----------------+---------------------+
# | 169             |                  81 |
# +-----------------+---------------------+
# | 147             |                  80 |
# +-----------------+---------------------+
# | 126             |                  79 |
# +-----------------+---------------------+
# | 16              |                  77 |
# +-----------------+---------------------+
# | 373-C           |                  77 |
# +-----------------+---------------------+
# | 107             |                  73 |
# ...

# %%
#November
#Top 50 Water Consumers
test = dataset.sort_values(['DIFF'], ascending = [False])
b =test[['Villa No. Nov', 'DIFF']]
info = b.head(50)
print(tabulate(info, headers = ['Villa No. Nov', 'Nov Water Reading'], tablefmt = 'grid', showindex = False))
# Out:
# +-----------------+---------------------+
# | Villa No. Nov   |   Nov Water Reading |
# +=================+=====================+
# | 169             |                  93 |
# +-----------------+---------------------+
# | 126             |                  92 |
# +-----------------+---------------------+
# | 752             |                  91 |
# +-----------------+---------------------+
# | 149             |                  84 |
# +-----------------+---------------------+
# | 371             |                  81 |
# +-----------------+---------------------+
# | 127             |                  80 |
# +-----------------+---------------------+
# | 709             |                  78 |
# +-----------------+---------------------+
# | 16              |                  78 |
# +-----------------+---------------------+
# | 272             |                  77 |
# +-----------------+---------------------+
# | 387             |                  77 |
# ...
